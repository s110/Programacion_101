# %% [markdown]
# <a href="https://colab.research.google.com/github/s110/Programacion_101/blob/main/01_Introduccion_a_Python/01_Fundamentos_de_Programaci%C3%B3n.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <img src="https://www.ctic.uni.edu.pe/wp-content/uploads/2022/04/588px-x-348px-web-1.png" alt="HTML5 Icon" width="900" height="350" >

# %% [markdown]
# <h1 align=center><font size = 5>FUNDAMENTOS DE PROGRAMACIÓN
# </font></h1>
#
# ---

# %% [markdown]
# ## Tabla de Contenidos
#
# <div class="alert alert-block alert-info" style="margin-top: 20px">
#
# <font size = 3>
#
# 1. <a href="#item31">Tipos básicos de datos</a>
# 2. <a href="#item31">Manipulación de strings</a>
# 3. <a href="#item31">Estructuras condicionales</a>
# 4. <a href="#item31">Desafío</a>
# </font>
# </div>
#
# ---

# %% [markdown]
# ## <b>Objetivo:</b>
#
# Desarrollar habilidades para trabajar con tipos de datos básicos, manipulación de cadenas y la aplicación de estructuras condicionales en Python.
#
# ---

# %% [markdown]
# ## <b>1. Tipos básicos de datos</b>
#
# Enteros, flotantes, cadenas y booleanos, con énfasis en cómo utilizarlos en operaciones básicas.

# %% [markdown]
# ### Verificando la versión de Python

# %%
# !python3
# Out:
# Python 3.10.12 (main, Jul 29 2024, 16:56:48) [GCC 11.4.0] on linux
# Type "help", "copyright", "credits" or "license" for more information.
# >>>
# KeyboardInterrupt
# >>>
# KeyboardInterrupt
# >>>
# KeyboardInterrupt
# >>> ^C

# %% [markdown]
# ### Ejecutando en Python

# %%
print("Hello Python interpreter!")
# Out:
# Hello Python interpreter!

# %% [markdown]
# ### Variables en Python

# %%
message = "Hello Python world!"
print(message)
# Out:
# Hello Python world!

# %% [markdown]
# ### Usando variables con strings

# %%
first_name = "Sebastian"
last_name = "Lopez Medina"

nombre_completo= first_name+' '+last_name
print(nombre_completo)
print(first_name,last_name, sep=',')

full_name = f"{first_name} {last_name}"
print(full_name)
# Out:
# Sebastian Lopez Medina
# Sebastian,Lopez Medina
# Sebastian Lopez Medina

# %%
age=input('Dime tu edad:')
print(age)
# Out:
# Dime tu edad:a
# a

# %%
first_name = str(input('Ingrese el primer nombre: '))
last_name = str(input('Ingrese el apellido: '))

full_name = f"{first_name} {last_name}"
print(f"Bienvenido al curso de programacion {full_name}!")
# Out:
# Ingrese el primer nombre: sebastian
# Ingrese el apellido: lopez
# Bienvenido al curso de programacion sebastian lopez!

# %%
print(f"Hola, {full_name.title()}!")
# Out:
# Hola, Sebastian Lopez!

# %%
message = f"Hola, {full_name.capitalize()}!"
print(message)
# Out:
# Hola, Sebastian lopez!

# %%
print("Python")
# Out:
# Python

# %%
print("Python's")
# Out:
# Python's

# %%
print("\tPython")
# Out:
# 	Python

# %%
print("Languages:\nPython\nC\nJavaScript")
# Out:
# Languages:
# Python
# C
# JavaScript

# %%
print("Languages:\n\tPython\n\tC\n\tJavaScript")
# Out:
# Languages:
# 	Python
# 	C
# 	JavaScript

# %% [markdown]
# ### Espacios en python

# %%
favorite_language = 'python '
favorite_language
# Out:
# 'python '

# %%
favorite_language.rstrip()
# Out:
# 'python'

# %%
favorite_language
# Out:
# 'python '

# %%
favorite_language = 'python '
favorite_language = favorite_language.rstrip()
favorite_language
# Out:
# 'python'

# %%
favorite_language = ' python '
favorite_language
# Out:
# ' python '

# %%
favorite_language.rstrip()
# Out:
# ' python'

# %%
favorite_language.lstrip()
# Out:
# 'python '

# %%
favorite_language.strip()
# Out:
# 'python'

# %% [markdown]
# ### Problemas comunes

# %%
message = "El libro 'Harry Potter' fue un best seller"
print(message)

# %%
message = 'One of Python's strengths is its diverse community.'
print(message)

# %% [markdown]
# ### Números

# %%
2 + 3
# Out:
# 5

# %%
3 ** 2
# Out:
# 9

# %%
(2 + 3) * 4
# Out:
# 20

# %%
import datetime
age_year=int(input('Año de nacimiento:'))
actual_year=datetime.datetime.now().year
print(f'Tu edad es {actual_year-age_year} años')
# Out:
# Año de nacimiento:1992
# Tu edad es 32 años

# %% [markdown]
# ### Floats

# %%
0.1 + 0.1
# Out:
# 0.2

# %%
2 * 0.2
# Out:
# 0.4

# %%
0.2 + 0.1
# Out:
# 0.30000000000000004

# %% [markdown]
# ### Enteros y Floats

# %%
4/2
# Out:
# 2.0

# %%
1 + 2.0
# Out:
# 3.0

# %%
1*3.0
# Out:
# 3.0

# %% [markdown]
# ### Guiones bajos en números

# %%
universe_age = 14_000_000_000
print(f'{universe_age:,}')
# Out:
# 14,000,000,000

# %% [markdown]
# ### Asignación Múltiple

# %%
a, b = 1, 2
b
# Out:
# 2

# %%
x, y, z = 0, 0, 0

# %%
y
# Out:
# 0

# %% [markdown]
# ### Constantes

# %%
MAX_CONNECTIONS = 5000

# %% [markdown]
# <b> Ejercicio </b>
#
# Usa una variable para representar un número. Luego, usando esa variable, cree un mensaje que revele su número. Imprime ese mensaje.

# %% [markdown]
# Doble-click __aquí__ para ver la solución.
# <!-- La respuesta es:
# num = 12
# print(f"El número es {num}")
# -->

# %% [markdown]
# ### Comentarios

# %%
# Código para saludar.
print("Hola programadores de Python!")
# Out:
# Hola programadores de Python!

# %% [markdown]
# ### El Zen de Python

# %%
import this
# Out:
# The Zen of Python, by Tim Peters
#
# Beautiful is better than ugly.
# Explicit is better than implicit.
# Simple is better than complex.
# Complex is better than complicated.
# Flat is better than nested.
# Sparse is better than dense.
# Readability counts.
# Special cases aren't special enough to break the rules.
# Although practicality beats purity.
# Errors should never pass silently.
# Unless explicitly silenced.
# In the face of ambiguity, refuse the temptation to guess.
# There should be one-- and preferably only one --obvious way to do it.
# Although that way may not be obvious at first unless you're Dutch.
# Now is better than never.
# Although never is often better than *right* now.
# If the implementation is hard to explain, it's a bad idea.
# If the implementation is easy to explain, it may be a good idea.
# Namespaces are one honking great idea -- let's do more of those!

# %% [markdown]
# ### Ejemplo 1.1: Operaciones aritméticas

# %%
# Variables numéricas
a = 3.0000 # Entero
b = 4.0  # Flotante

# %%
# Operaciones básicas
print("Suma:", a + b)
# Out:
# Suma: 7.0

# %%
print("Resta:", a - b)
# Out:
# Resta: -2.3095842401765703

# %%
print("Multiplicación:", a * b)
# Out:
# Multiplicación: 32.83291031876401

# %%
print("División:", a / b)
# Out:
# División: 1.5714285714285714

# %%
print("Módulo:", a % b)  # Residuo de la división
# Out:
# Módulo: 4

# %% [markdown]
# ### Ejercicio 1.1: Operaciones con entrada de usuario
#
# Pide al usuario dos números, realiza las operaciones básicas (suma, resta, multiplicación y división) e imprime los resultados.
# Calcula la raíz cuadrada de un número utilizando la función ** (exponente).

# %%
i,j=float(input('primer num:')),float(input('segundo num:'))
print(f'suma:{i+j} \nresta:{i-j} \nmultiplicacion:{i*j} \ndivision:{i/j} \nraiz cuadrada:{i**0.5}')
# Out:
# primer num:25
# segundo num:7.8
# suma:32.8
# resta:17.2
# multiplicacion:195.0
# division:3.2051282051282053
# raiz cuadrada:5.0

# %% [markdown]
# ## <b>2. Manipulación de strings</b>
#
# Las cadenas de texto (strings) en Python son secuencias de caracteres, y Python proporciona muchos métodos útiles para manipularlas.

# %% [markdown]
# ### Ejemplo 2.1: Concatenación y repetición de cadenas

# %%
nombre = "Ana"
apellido = "Sánchez"
nombre_completo = nombre + " " + apellido

print("Nombre completo:", nombre_completo)
# Out:
# Nombre completo: Ana Sánchez

# %%
# Repetición

repetido = "Python! " * 3
print(repetido)
# Out:
# Python! Python! Python!

# %% [markdown]
# ### Ejercicio 2.1: Creando saludos
#
# - Pide al usuario su nombre y apellido, luego genera un saludo en el formato: "¡Hola, [Nombre Apellido]!".
#
# - Usa repetición para imprimir el saludo 5 veces.

# %% [markdown]
# ### Ejemplo 2.2: Métodos strip(), lstrip() y rstrip()

# %%
# Métodos para eliminar espacios

texto = "   Python es genial   "
print("Original:", texto)

# %%
print("Con strip():", texto.strip())    # Elimina espacios al inicio y final

# %%
print("Con lstrip():", texto.lstrip())  # Elimina espacios al inicio

# %%
print("Con rstrip():", texto.rstrip())  # Elimina espacios al final

# %% [markdown]
# ### Ejercicio 2.2: Eliminar espacios en cadenas
#
# Pide al usuario que ingrese una frase con espacios extra al inicio y al final.
#
# - Usa strip() para eliminar los espacios en blanco.
# - Usa lstrip() para eliminar los espacios al inicio.
# - Usa rstrip() para eliminar los espacios al final.
#
# Imprime los resultados después de aplicar cada método.

# %%
oracion_strip=input('Ingrese una frase con espacios extra al inicio y al final:')
print(f'Usando strip() para eliminar los espacios en blanco:{oracion_strip.strip()}')
print(f'Usando lstrip() para eliminar los espacios al inicio:{oracion_strip.lstrip()}')
print(f'Usando rstrip() para eliminar los espacios al final:{oracion_strip.rstrip()}')
# Out:
# Ingrese una frase con espacios extra al inicio y al final:            hola amigos :3
# Usando strip() para eliminar los espacios en blanco:hola amigos :3
# Usando lstrip() para eliminar los espacios al inicio:hola amigos :3
# Usando rstrip() para eliminar los espacios al final:            hola amigos :3

# %% [markdown]
# ### Ejemplo 2.3: Métodos adicionales de cadenas

# %%
# Otros métodos útiles
texto = "Hola Pythonista"

# %%
print(texto.upper())  # Convierte todo a mayúsculas

# %%
print(texto.lower())  # Convierte todo a minúsculas

# %%
print(texto.replace("Pythonista", "Programador"))  # Reemplaza una palabra

# %% [markdown]
# ### Ejercicio 2.3: Transformando cadenas
#
# Pide al usuario que ingrese una frase, luego:
# - Convierte toda la frase a mayúsculas.
# - Reemplaza una palabra de la frase por otra y muestra el resultado.
# - Imprime la longitud de la frase.

# %%
oracion_format=input('Ingrese una frase:')
print('Oracion en mayúsculas:',oracion_format.upper())
print('Oracion con reemplazo:',oracion_format.replace('a','c'))
print('Longitud de frase',len(oracion_format))
# Out:
# Ingrese una frase:a nisman lo mataron
# Oracion en mayúsculas: A NISMAN LO MATARON
# Oracion con reemplazo: c nismcn lo mctcron
# Longitud de frase 19

# %% [markdown]
# ## <b>3. Estructuras de control: Condicionales</b>

# %% [markdown]
# Las estructuras condicionales permiten que un programa tome decisiones en función de las condiciones que se cumplan.

# %% [markdown]
# ### Igualdades

# %%
1 ==2
# Out:
# False

# %%
1 == 2
# Out:
# False

# %%
2 == 2
# Out:
# True

# %%
2 == 2.0
# Out:
# True

# %%
car = 'bmw'
car == 'bmw'
# Out:
# True

# %%
car = 'audi'
car == 'bmw'
# Out:
# False

# %% [markdown]
# Ignorando Mayusculas en igualdades

# %%
car = 'Audi'
car == 'audi'
# Out:
# False

# %%
car.lower()
# Out:
# 'audi'

# %%
car.upper()

# %%
car = 'Audi'
car.lower() == 'audi'

# %% [markdown]
# ### Desigualdades

# %%
1 != 2

# %%
'Audi' != 'audi'

# %%
2 != 2.0

# %%
requested_topping = 'champiñones'

if requested_topping != 'Anchoas':
  print("Sostén las Anchoas!")

# %% [markdown]
# ### Comparar Números

# %%
age = 18
age == 18

# %%
answer = 17

if answer != 42:
  print("Respuesta incorrecta, intenta nuevamente!")

# %%
answer = int(input('Ingrese su respuesta: '))

if answer != 42:
  print("Respuesta incorrecta, intenta nuevamente!")

# %%
age = 19
age < 21

# %%
age <= 21

# %%
age > 21

# %%
age >= 21

# %% [markdown]
# ### Condicionales múltiples

# %%
age_0 = 22
age_1 = 18
age_0 >= 21 and age_1 >= 21

# %%
age_1 = 22
age_0 >= 21 and age_1 >= 21

# %%
(age_0 >= 21) and (age_1 >= 21)

# %%
age_0 = 22
age_1 = 18
age_0 >= 21 or age_1 >= 21

# %%
age_0 = 18
age_0 >= 21 or age_1 >= 21

# %% [markdown]
# ### Ejemplo 3.1: Condicionales simples (if, else, elif)

# %%
edad = int(input("¿Cuántos años tienes? "))

if edad >= 18:
    print("Eres mayor de edad.")
else:
    print("Eres menor de edad.")

# %% [markdown]
# ### Ejercicio 3.1: Descuento basado en la edad
#
# Pide al usuario ingresar su edad y usa condicionales para aplicar los siguientes descuentos:
# - Si es menor de 18 años, obtiene un 50% de descuento.
# - Si tiene entre 18 y 65 años, obtiene un 10% de descuento.
# - Si es mayor de 65 años, obtiene un 30% de descuento.

# %%
#Considerado que no puede existir edad negativa pero aun asi protegiendo contra edades negativas.
edad=abs(int(input('Ingrese su edad:')))
if edad < 18:
  print('50% descuento')
elif edad >65:
  print('30% descuento')
else:
  print('10% descuento')
# Out:
# Ingrese su edad:-30
# 10% descuento

# %% [markdown]
# ### Ejemplo 3.2: Condicionales con varias condiciones

# %%
temperatura = int(input("¿Cuál es la temperatura actual en grados? "))

if temperatura > 30:
    print("Hace mucho calor.")
elif temperatura > 20:
    print("El clima es agradable.")
else:
    print("Hace frío.")

# %% [markdown]
# ### Ejercicio 3.2: Estado de la temperatura
#
# Crea un programa que pida al usuario la temperatura en su ciudad y determine:
# - Si es mayor de 30 grados, imprime "Hace mucho calor".
# - Si está entre 20 y 30 grados, imprime "El clima es agradable".
# - Si es menor de 20 grados, imprime "Hace frío".

# %%
temp=float(input('Ingrese la temperatura de su ciudad:'))
if temp>30:
  print('Hace mucho calor')
elif temp<20:
  print('Hace frío')
else:
  print('El clima es agradable')
# Out:
# Ingrese la temperatura de su ciudad:-30
# Hace frío

# %% [markdown]
# ### Ejemplo 3.3: Anidamiento de condicionales

# %%
edad = int(input("¿Cuál es tu edad? "))
ingreso = int(input("¿Cuál es tu ingreso mensual en USD? "))

if edad >= 18:
    if ingreso >= 1000:
        print("Puedes solicitar una tarjeta de crédito.")
    else:
        print("No tienes suficiente ingreso para solicitar una tarjeta.")
else:
    print("Debes ser mayor de 18 para solicitar una tarjeta.")

# %% [markdown]
# ### Ejercicio 3.3: Sistema de votación
#
# Crea un programa que determine si una persona puede votar. Pide al usuario su nacionalidad y edad.
# - Si la persona es de nacionalidad "Peruana" y mayor de 18 años, permite que vote.
# - Si es menor de edad o no es de esa nacionalidad, no puede votar.

# %%
nacionalidad,edad=input('Ingresa nacionalidad:'),int(input('Ingresa edad:'))
if (nacionalidad=='Peruana') and (edad>18):
  print('Puedes votar')
else:
  print('No puedes votar')

# %% [markdown]
# ### Ejemplo 3.4: Condicionales con operadores lógicos

# %%
nota = int(input("¿Cuál es tu nota? "))

if nota >= 90 and nota <= 100:
    print("Excelente")
elif nota >= 70 and nota < 90:
    print("Aprobado")
else:
    print("Reprobado")

# %% [markdown]
# ### Ejercicio 3.4: Notas de estudiantes
#
# Escribe un programa que determine la calificación de un estudiante en función de su nota:
# - Si la nota es mayor o igual a 90: "Sobresaliente".
# - Si está entre 70 y 89: "Aprobado".
# - Si es menor de 70: "Desaprobado".

# %%
nota=float(input('Ingrese nota:'))
if nota>=90:
  print('Sobresaliente')
elif nota<70:
  print('Desaprobado')
else:
  print('Aprobado')

# %% [markdown]
# ## <b>4. Desafío</b>

# %% [markdown]
# ### Desafío 1: Calculadora de propinas inteligente
#
# Crea un programa que simule una calculadora de propinas en un restaurante. El programa debe:
#
# - Pedir al usuario que ingrese el total de la cuenta.
# - Pedir el porcentaje de propina que le gustaría dejar (por ejemplo, 10%, 15%, 20%).
#
# Usar condicionales para sugerir automáticamente un valor si no se ingresa un porcentaje, basándose en la experiencia:
#
# - Si el servicio fue excelente, sugerir 20%.
# - Si el servicio fue bueno, sugerir 15%.
# - Si el servicio fue mediocre, sugerir 10%.
# - Si el servicio fue malo, no sugerir propina.
#
# Calcular e imprimir la cantidad de propina y el total a pagar (cuenta + propina).

# %%
total_cuenta=float(input('Ingrese el total de la cuenta en soles:'))
satisfaccion=int(input('Del 1 al 4 que le parecio el servicio? (Siendo 4 excelente y 1 malo):'))
#aca se podria usar switch?
if satisfaccion==4:
  p_sugerida=20
elif satisfaccion==3:
  p_sugerida=15
elif satisfaccion==2:
  p_sugerida=10
elif satisfaccion==1:
  p_sugerida=0
else:
  print('Ingrese un valor de satisfaccion valido')
  exit()
propina=float(input(f'Ingrese el porcentaje de propina en NUMERO (Propina sugerida:{p_sugerida}%):'))

print(f'Lo pagado con un {round(propina,2)}% de propina es S/.{round(propina*total_cuenta/100,2)} en propinas y S/.{round((1.0+propina/100)*total_cuenta,2)} en total')

# %% [markdown]
# ### Desafío 2: Clasificación de Números
#
# Escribe un programa que clasifique un número dado por el usuario según sus características numéricas. El programa debe:
#
# Pedir al usuario que ingrese un número entero.
#
# Determinar si el número es:
# - Par o impar.
# - Positivo, negativo o cero.
# - Primo o no primo (un número primo solo es divisible por 1 y por sí mismo).
# - Imprimir una clasificación completa del número según las tres categorías anteriores.

# %%
numero=int(input('Ingrese un numero entero:'))

if (numero%2==0):
    out_1='par'
else:
    out_1='impar'

if (numero >0):
    out_2='positivo'
elif (numero<0):
    out_2='negativo'
else:
    out_2='cero'

#mala performance jajaja
out_3='primo'
for i in range(2,numero):
    if numero%i==0:
        out_3='no primo'
        break
print(f'El número {numero} es {out_1}, {out_2}, y {out_3}')

# %% [markdown]
# ---
#
# # Gracias por completar este laboratorio!
#
# ---
